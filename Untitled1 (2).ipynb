# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate
import functools
import math
import pandas as pd
from scipy.interpolate import lagrange
from numpy.polynomial.polynomial import Polynomial

# %%
def f(x):
    return np.log(1 + x) * np.cos(50 * x)
def g(x):
    return np.log(1 + x)

# %%
def exp_taylor(x, m, degree):
    res = sum( (m ** k) * x ** k / math.factorial(k) for k in range(degree))
    return  res

# %%
exp_taylor(2, 1, 10)
# Out:
# 7.3887125220458545

# %%
x_data = np.arange(0, 4, 0.01)

h = np.vectorize(lambda x: exp_taylor(x, 1, 12))
plt.plot(x_data, np.exp(-x_data))
plt.plot(x_data, h(x_data))

# %%
x_data = np.arange(0, 4, 0.00001)

plt.plot(x_data, f(x_data), label=r"$e^{-x} \cos (40 x)$")
plt.plot(x_data, g(x_data), label=r"$e^{-x}$")
plt.legend()
#plt.savefig("pl.png", dpi=300)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
def integrate_simp(f, a, b, n: int =1000):
    """
    :n кількість вузлів
    """
    n = (n + 1) if n % 2 == 0 else n
    
    h = (b - a) / (n - 1)
    x = np.linspace(a, b, n)
    f_ = f(x)
    
    I_simp = (h / 3) * (f_[0] + 4 * sum(f_[1:n-1:2]) + 2 * sum(f_[2:n-2:2]) + f_[n-1])
    
    return I_simp

print(type(integrate_simp))
# Out:
# <class 'function'>

# %%
n_intervals = 2
h = (0 + 4) / n_intervals
I_1 = integrate_simp(f, 0, 4, 2 + 1)
I_1_2 = integrate_simp(f, 0, 4, 4 + 1)
eps = 10e-5
i = 1
while abs(I_1 - I_1_2) / (2 ** 4 - 1) > eps:
    print(f"n = {n_intervals}, 2n = {2*n_intervals}")
    print(f"h = {h}, h/2 = {h/2}")
    n_intervals *= 2
    I_1 = integrate_simp(f, -3, 1, n_intervals + 1)
    I_1_2 = integrate_simp(f, -3, 1, 2 * n_intervals + 1)
    h = (1 + 3) / n_intervals
    print(f"I_h = {I_1}, I_h/2 = {I_1_2}")
    if abs(I_1 - I_1_2) / (2 ** 4 - 1) > eps:
        print(f"|I_h - I_h/2| / (2^4 -1)  = {abs(I_1 - I_1_2) / (2 ** 4 - 1)} > {eps}")
    else:
        print(f"|I_h - I_h/2| / (2^4 -1)  = {abs(I_1 - I_1_2) / (2 ** 4 - 1)} <  {eps}")
    print()
# Out:
# n = 2, 2n = 4
# h = 2.0, h/2 = 1.0
# I_h = 4.40647592250837, I_h/2 = 6.913192784859939
# |I_h - I_h/2| / (2^4 -1)  = 0.16711445749010465 > 0.0001
#
# n = 4, 2n = 8
# h = 1.0, h/2 = 0.5
# I_h = 6.913192784859939, I_h/2 = -2.468721303977983
# |I_h - I_h/2| / (2^4 -1)  = 0.6254609392558614 > 0.0001
#
# n = 8, 2n = 16
# h = 0.5, h/2 = 0.25
# I_h = -2.468721303977983, I_h/2 = -1.0264966291209785
# |I_h - I_h/2| / (2^4 -1)  = 0.09614831165713364 > 0.0001
#
# n = 16, 2n = 32
# h = 0.25, h/2 = 0.125
# I_h = -1.0264966291209785, I_h/2 = 0.45849525989100726
# |I_h - I_h/2| / (2^4 -1)  = 0.09899945926746571 > 0.0001
#
# n = 32, 2n = 64
# h = 0.125, h/2 = 0.0625
# I_h = 0.45849525989100726, I_h/2 = 0.3129235771469231
# |I_h - I_h/2| / (2^4 -1)  = 0.00970477884960561 > 0.0001
#
# n = 64, 2n = 128
# h = 0.0625, h/2 = 0.03125
# I_h = 0.3129235771469231, I_h/2 = 0.30881737584743374
# |I_h - I_h/2| / (2^4 -1)  = 0.00027374675329929025 > 0.0001
#
# n = 128, 2n = 256
# h = 0.03125, h/2 = 0.015625
# I_h = 0.30881737584743374, I_h/2 = 0.3085955344586014
# |I_h - I_h/2| / (2^4 -1)  = 1.478942592215704e-05 <  0.0001

# %%
plt.plot(x_data, g(x_data), label=r"$e^x$")
plt.legend()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
def approx(x, coefs):
    n = len(coefs)
    I = sum((x ** i) * coefs[i] for i in range(n))
    
    return I

# %%
plt.plot(x_data, [approx(x, c) for x in x_data], label=r"approx")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-2f33acfb3d42> in <module>
# ----> 1 plt.plot(x_data, [approx(x, c) for x in x_data], label=r"approx")
#       2 plt.legend()
#
# <ipython-input-31-2f33acfb3d42> in <listcomp>(.0)
# ----> 1 plt.plot(x_data, [approx(x, c) for x in x_data], label=r"approx")
#       2 plt.legend()
#
# NameError: name 'c' is not defined

# %%
@functools.lru_cache(maxsize=256)
def trig_int(a, b, k, flag, m=50):
    assert type(k) == int, "int"
    assert flag == "sin" or flag == "cos", "sin or cos"
    
    def xk_sinmx(x): return (x ** k) * np.sin(m * x)
    def xk_cosmx(x): return (x ** k) * np.cos(m * x)
    def fb_fa(f, a, b): return f(b) - f(a)
    
    if k == 0:
        if flag == "cos":  # int_a^b cos(mx) dx
            return (1 / m) * (np.sin(b * m) - np.sin(a * m))
        
        # int_a^b sin(mx) dx
        return -(1 / m) * (np.cos(b * m) - np.cos(a * m))
    if flag == "cos":  # int_a^b x^k * cos(mx)dx
        return (1 / m) * ( 
                fb_fa(xk_sinmx, a, b)
                - k * trig_int(a, b, k - 1, "sin", m)
            )
    
    # int_a^b x^k * sin(mx)dx
    return (-1 / m) * ( 
            fb_fa(xk_cosmx, a, b)
            - k * trig_int(a, b, k - 1, "cos", m)
        )

def approx_coef(f, a, b, n: int =3):

    def base_prod(i, j, a, b):
        return (
            ((b**(i + j + 1)) - (a**(i + j + 1))) 
            / (i + j  +1)
        )

    A_xi = (
        np.array([[base_prod(i, j, a, b) for j in range(n)] for i in range(n)])
    )

    b_xi = np.array([ scipy.integrate.quad(lambda x: f(x) * x**i, a, b)[0] for i in range(n)])

    x_sol_xi = np.linalg.solve(A_xi, b_xi)
    
    return x_sol_xi

# %%
c_1 = approx_coef(g, 0, 4, 7)
c_2 = approx_coef(g, 0, 4, 8)

# %%
integral_philon_1 = sum(c_1[i] * trig_int(0, 4, k=i, flag="cos", m = 50) for i in range(len(c_1)))
integral_philon_2 = sum(c_2[i] * trig_int(0, 4, k=i, flag="cos", m = 50) for i in range(len(c_2)))
print(abs(integral_philon_1 - integral_philon_2))
print(integral_philon_2)
# Out:
# 1.4909162057055725e-05
# -0.028470596540731176

# %%
I_2 = scipy.integrate.quad(lambda x: g(x) * np.cos(50 * x), 0, 4)
print(I_2)
# Out:
# (-0.02847134275849445, 1.6015240921624097e-09)

# %%
def cheb_nodes(left, right, n):
    res = np.array([
        (1/2 * (left + right)) 
            + ((1 / 2 * (right - left)) * math.cos((2 * k - 1) * math.pi / (2 * n)))
           for k in range(1, n + 1)])
    return res[::-1]

# %%
n_intervals = 2
n_nodes = n_intervals + 1
h = 4 / n_intervals

c_nodes_1 = cheb_nodes(0, 4, n_nodes)
c_nodes_2 = cheb_nodes(0, 4, 2*n_nodes)

v_1 = [np.log(1 + x) for x in c_nodes_1]
v_2 = [np.log(1 + x) for x in c_nodes_2]

poly_1 = lagrange(c_nodes_1, v_1)
poly_2 = lagrange(c_nodes_2, v_2)

coefs_1 = Polynomial(poly_1).coef
coefs_2 = Polynomial(poly_2).coef

I_p_1 = sum(coefs_1[-(i+1)] * trig_int(0, 4, k=i, flag="cos", m = 50) for i in range(len(coefs_1)))
I_p_2 = sum(coefs_2[-(i+1)] * trig_int(0, 4, k=i, flag="cos", m = 50) for i in range(len(coefs_2)))

while abs(I_p_1 - I_p_2) > eps:
    print(f"n = {n_intervals}, 2n = {2*n_intervals}")
    print(f"h = {h}, h/2 = {h/2}")
    h = 4 / n_intervals
    
    c_nodes_1 = cheb_nodes(0, 4, n_intervals + 1)
    c_nodes_2 = cheb_nodes(0, 4, 2*n_intervals + 1)

    v_1 = [np.log(1 + x) for x in c_nodes_1]
    v_2 = [np.log(1 + x) for x in c_nodes_2]

    poly_1 = lagrange(c_nodes_1, v_1)
    poly_2 = lagrange(c_nodes_2, v_2)

    coefs_1 = Polynomial(poly_1).coef
    coefs_2 = Polynomial(poly_2).coef

    I_p_1 = sum(coefs_1[-(i+1)] * trig_int(0, 4, k=i, flag="cos", m = 50) for i in range(len(coefs_1)))
    I_p_2 = sum(coefs_2[-(i+1)] * trig_int(0, 4, k=i, flag="cos", m = 50) for i in range(len(coefs_2)))
    print(f"I_h = {I_p_1}, I_h/2 = {I_p_2}")
    if abs(I_p_1 - I_p_2) > eps:
        print(f"|I_h - I_h/2| = {abs(I_p_1 - I_p_2)} > {eps}")
    else:
        print(f"|I_h - I_h/2| = {abs(I_p_1 - I_p_2)} <  {eps}")
    print()
    n_intervals *= 2
# Out:
# n = 2, 2n = 4
# h = 2.0, h/2 = 1.0
# I_h = -0.027986971737835115, I_h/2 = -0.0284130804321052
# |I_h - I_h/2| = 0.0004261086942700838 > 0.0001
#
# n = 4, 2n = 8
# h = 2.0, h/2 = 1.0
# I_h = -0.0284130804321052, I_h/2 = -0.028469987931661507
# |I_h - I_h/2| = 5.690749955630792e-05 <  0.0001

# %%
def f_approximate(x, c: list):
    n = len(c)
    return sum(coefs[-(i+1)] * x ** i for i in range(n))

y_data = [f_approximate(x, coefs) for x in x_data]

plt.plot(x_data, y_data)
plt.plot(x_data, np.exp(-x_data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-6661c39bb1bb> in <module>
#       3     return sum(coefs[-(i+1)] * x ** i for i in range(n))
#       4
# ----> 5 y_data = [f_approximate(x, coefs) for x in x_data]
#       6
#       7 plt.plot(x_data, y_data)
#
# <ipython-input-51-6661c39bb1bb> in <listcomp>(.0)
#       3     return sum(coefs[-(i+1)] * x ** i for i in range(n))
#       4
# ----> 5 y_data = [f_approximate(x, coefs) for x in x_data]
#       6
#       7 plt.plot(x_data, y_data)
#
# NameError: name 'coefs' is not defined
